# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # Features
# - 'Id'
# - 'EmployeeName'
# - 'JobTitle'
# - 'BasePay'
# - 'OvertimePay'
# - 'OtherPay'
# - 'Benefits'
# - 'TotalPay' -> salary
# - 'TotalPayBenefits'
# - 'Year'
# - 'Notes'
# - 'Agency'
# - 'Status'

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# #### Very Important Note
# There is no fixed or singular solution for this assignment, so if anything is not clear, please do what you understand and provide an explanation.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv('/content/drive/MyDrive/ShaiForAI/ApplicationAssignment/Salaries.csv')
df.tail(50)
# Out:
#             Id                EmployeeName                      JobTitle  \
# 148604  148605              Sugyn M Paynay    Publ Svc Aide-Asst to Prof
# 148605  148606             Edwina V Brinas              Registered Nurse
# 148606  148607               Randall Cinti         School Crossing Guard
# 148607  148608           Gary C Schoenfeld                Pool Lifeguard
# 148608  148609          Elsa N Evangelista              Registered Nurse
# 148609  148610              Tucker L Silva                Pool Lifeguard
# 148610  148611               Ruby S Martin                 Special Nurse
# 148611  148612  Patricia M Mackey-Williams        Patient Care Assistant
# 148612  148613            Kermith T Miller               Utility Plumber
# 148613  148614             Nanette M Lloyd                 Special Nurse
# 148614  148615               Tracy Dickson     Licensed Vocational Nurse
# 148615  148616               Marilou P Gan              Registered Nurse
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %% [markdown]
# ### 1- Basic Data Exploration: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
print(f"The number of columns: {df.shape[1]} \nThe number of rows: {df.shape[0]})")
# Out:
# The number of columns: 13
# The number of rows: 148654)

# %%
print("The number of missing values in each column :")

df.isnull().sum()
# Out:
# The number of missing values in each column :
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %% [markdown]
# ### 2-Descriptive Statistics: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
#
# ---

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148603.000000  148603.000000  148603.000000  148603.000000
# mean    66074.320959    5067.637113    3649.896100   18929.942912
# std     42877.927450   11455.846974    8057.562248   17164.838366
# min         0.000000       0.000000       0.000000       0.000000
# 25%     32857.500000       0.000000       0.000000       0.000000
# 50%     64881.130000       0.000000     812.970000   23240.840000
# 75%     94611.010000    4660.360000    4238.140000   33470.900000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148603.000000     148603.000000  148603.000000
# mean    74791.854172      93721.797084    2012.522399
# std     50508.281781      62782.280230       1.117503
# min         0.000000          0.300000    2011.000000
# 25%     36211.030000      44164.025000    2012.000000
# ...

# %%
print("The basic descriptive statistics for salaries: ")
print(f"Mean: {df['TotalPay'].mean()}")
print(f"Median: {df['TotalPay'].median()}")
print(f"Mode: {df['TotalPay'].mode()}")
print(f"Minimum: {df['TotalPay'].min()}")
print(f"Maximum: {df['TotalPay'].max()}")
print(f"The range of salaries: {df['TotalPay'].min()} To {df['TotalPay'].max()}")
print(f"std: {df['TotalPay'].std()}")
# Out:
# The basic descriptive statistics for salaries:
# Mean: 74791.85417171927
# Median: 71439.31
# Mode: 0    0.0
# Name: TotalPay, dtype: float64
# Minimum: 0.0
# Maximum: 567595.43
# The range of salaries: 0.0 To 567595.43
# std: 50508.281780544734

# %% [markdown]
# ##### Dealing with outliers:

# %% [markdown]
# It doesn't make sense to have negative values for pays or benefits, so I decided to delete the rows containing negative values
# But we can't decide if the maximum salaries should concidered as an outlier or not so I will keep them

# %%
# Count rows with negative values
num_Negative_TotalPay=df[df['TotalPay'] < 0].shape[0]
num_Negative_BasePay=df[df['BasePay'] < 0].shape[0]
num_Negative_OvertimePay=df[df['OvertimePay'] < 0].shape[0]
num_Negative_OtherPay=df[df['OtherPay'] < 0].shape[0]
num_Negative_Benefits=df[df['Benefits'] < 0].shape[0]
num_Negative_TotalPayBenefits=df[df['TotalPayBenefits'] < 0].shape[0]

print(f"num_Negative_TotalPay: {num_Negative_TotalPay}")
print(f"num_Negative_BasePay: {num_Negative_BasePay}")
print(f"num_Negative_OvertimePay: {num_Negative_OvertimePay}")
print(f"num_Negative_OtherPay: {num_Negative_OtherPay}")
print(f"num_Negative_Benefits: {num_Negative_Benefits}")
print(f"num_Negative_TotalPayBenefits: {num_Negative_TotalPayBenefits}")
# Out:
# num_Negative_TotalPay: 0
# num_Negative_BasePay: 0
# num_Negative_OvertimePay: 0
# num_Negative_OtherPay: 0
# num_Negative_Benefits: 0
# num_Negative_TotalPayBenefits: 0

# %%
# Drop rows with negative values
df = df[df['TotalPay'] >= 0]
df = df[df['BasePay'] >= 0]
df = df[df['OvertimePay'] >= 0]
df = df[df['Benefits'] >= 0]
df = df[df['OtherPay'] >= 0]
df = df[df['TotalPayBenefits'] >= 0]

# %% [markdown]
# ### 3-Data Cleaning: Handle missing data by suitable method with explain why you use it.
#
#
# ---

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %% [markdown]
# Drop columns which totally full of missing values (Notes, Status)

# %%
df.drop(columns=["Notes","Status"],inplace=True)

# %%
df.drop(columns=["Id","Agency"],inplace=True) #not necessary for analysis

# %%
df.shape
# Out:
# (148603, 9)

# %% [markdown]
# Drop null values in (OvertimePay,OtherPay)
#
# Explanation: small neglected number of missing values compared to total

# %%
df.dropna(subset=["OvertimePay","OtherPay"],inplace=True)
df.shape
# Out:
# (148650, 11)

# %% [markdown]
# I noticed that there are some rows in which all values are zeros or missing.
# so, I decided to drop these rows (26 rows)

# %%
# Drop rows where all specified columns are either zeros or NaNs
df = df[~((df['BasePay'].eq(0) | df['BasePay'].isna()) &
          (df['OvertimePay'].eq(0) | df['OvertimePay'].isna()) &
          (df['OtherPay'].eq(0) | df['OtherPay'].isna()) &
          (df['Benefits'].eq(0) | df['Benefits'].isna()) &
          (df['TotalPay'].eq(0) | df['TotalPay'].isna()) &
          (df['TotalPayBenefits'].eq(0) | df['TotalPayBenefits'].isna()))]
df.shape
# Out:
# (148624, 11)

# %%
df.tail(100)
# Out:
#             Id             EmployeeName                      JobTitle  \
# 148527  148528           Robert E Pitts               Health Worker 1
# 148528  148529  Tierney M Keane-Zirpolo  Public Svc Aide-Public Works
# 148529  148530           Leaotis Martin  Public Svc Aide-Public Works
# 148530  148531              Janet N Qiu  Public Svc Aide-Public Works
# 148531  148532          Jose D Bermudez  Public Svc Aide-Public Works
# ...        ...                      ...                           ...
# 148622  148623       Jacqueline Hubbard                  Senior Clerk
# 148623  148624          Deborah B Honig     Attorney (Civil/Criminal)
# 148624  148625       Lorraine Rosenthal                  Senior Clerk
# 148625  148626          Renato C Gurion              Registered Nurse
# 148653  148654                Joe Lopez    Counselor, Log Cabin Ranch
#
#         BasePay  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
df.isnull().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36156
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
# show the rows where BasePay is NaN
df[df['BasePay'].isna()]
# Out:
#             Id       EmployeeName                   JobTitle  BasePay  \
# 81391    81392    Kevin P Cashman             Deputy Chief 3      NaN
# 84506    84507  Demetrya  Mullens  Licensed Vocational Nurse      NaN
# 84960    84961    Michael M Horan        Park Patrol Officer      NaN
# 90525    90526       Thomas  Tang           Police Officer 3      NaN
# 90786    90787     Michael C Hill             Deputy Sheriff      NaN
# ...        ...                ...                        ...      ...
# 110526  110527     Arthur L Curry    PS Aide Health Services      NaN
# 110527  110528      Nereida  Vega               Senior Clerk      NaN
# 110528  110529   Timothy E Gibson           Police Officer 3      NaN
# 110529  110530     Mark E Laherty           Police Officer 3      NaN
# 110530  110531      David P Kucia           Police Officer 3      NaN
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %% [markdown]
# Fill null values in (BasePay)
#
# Explanation:
# BasePay = TotalPay - OtherPay + OvertimePay

# %%
basePay = df['TotalPay']-(df['OtherPay']+df['OvertimePay'])
df['BasePay'].fillna(basePay, inplace=True)

# %%
df.iloc[81391]
# Out:
# Id                               81395
# EmployeeName               Irene  Wong
# JobTitle            Building Inspector
# BasePay                      110296.53
# OvertimePay                        0.0
# OtherPay                       3801.67
# Benefits                      35792.69
# TotalPay                      114098.2
# TotalPayBenefits             149890.89
# Year                              2013
# Agency                   San Francisco
# Name: 81394, dtype: object

# %%
# show the rows where Benefits is NaN
df[df['Benefits'].isna()]
# Out:
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 36151  36152        MARVA MOORE
# 36152  36153    MARCELLA TUCKER
# 36153  36154      ROCK CRAWFORD
# 36154  36155      SERENA HUGHES
# 36155  36156       JOE BROWN JR
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %% [markdown]
# Fill null values in (Benefits)
#
# Explanation: Benefits= TotalPayBenefits-TotalPay

# %%
benefits = df['TotalPayBenefits']-df['TotalPay']
df['Benefits'].fillna(round(benefits), inplace=True)

# %%
df.iloc[1]
# Out:
# Id                                                2
# EmployeeName                           GARY JIMENEZ
# JobTitle            CAPTAIN III (POLICE DEPARTMENT)
# BasePay                                   155966.02
# OvertimePay                               245131.88
# OtherPay                                  137811.38
# Benefits                                        0.0
# TotalPay                                  538909.28
# TotalPayBenefits                          538909.28
# Year                                           2011
# Agency                                San Francisco
# Name: 1, dtype: object

# %%
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %% [markdown]
# ### 4- Basic Data Visualization: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
#
# ---

# %%
import matplotlib.pyplot as plt

plt.hist(df['TotalPay'], bins=30, color='skyblue', edgecolor='black')
plt.ylim(0, 30000)
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
department_counts = df['JobTitle'].value_counts()
maxCountsDepts = department_counts.head(12)

otherDepts=department_counts[12:].sum()

newDeptCounts=maxCountsDepts.append(pd.Series({"Other departments" :otherDepts}))

# Plot a pie chart
plt.pie(newDeptCounts, labels=newDeptCounts.index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Employees in Different Departments')
plt.show()
# Out:
# <ipython-input-52-ccd1a4cede72>:6: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newDeptCounts=maxCountsDepts.append(pd.Series({"Other departments" :otherDepts}))

# %% [markdown]
# ###5- Grouped Analysis: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
#
# ---

# %% [markdown]
# Here I grouped the data based on the job title to show the average salaries for each job

# %%
grouped_data = df.groupby('JobTitle')

# Calculate the average salary for each Job group
average_salaries = grouped_data['TotalPay'].mean()

# Print the summary statistics
print(average_salaries.sort_values(ascending=False))
# Out:
# JobTitle
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    399211.275000
# Chief Investment Officer                          339653.700000
# Chief of Police                                   329183.646667
# Chief, Fire Department                            325971.683333
# DEPUTY DIRECTOR OF INVESTMENTS                    307899.460000
#                                                       ...
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN              149.510000
# Commissioner 16.700c, No Pay                          25.760000
# Drug Court Coordinator                                 0.000000
# IS Technician Assistant                                0.000000
# Public Safety Comm Tech                                0.000000
# Name: TotalPay, Length: 2158, dtype: float64

# %% [markdown]
# ###6- Simple Correlation Analysis: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
#
# ---

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
import seaborn as sns

numCols=df.select_dtypes(include=['float64', 'int64']).columns.drop('Id')

# Create a correlation matrix
correlation_matrix = df[numCols].corr()

# Create a heatmap using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap between TotalPay and Numerical Columns')
plt.show()

# %%
# Create a grid of subplots
num_plots = len(numCols)
num_cols = 4 # Number of columns in the grid
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 5 * num_rows))

# Plot each scatter plot in a separate subplot
for i, col in enumerate(numCols):
    row_index = i // num_cols
    col_index = i % num_cols
    sns.scatterplot(data=df, x='TotalPay', y=col, ax=axes[row_index, col_index])
    axes[row_index, col_index].set_title(f'Scatter Plot: TotalPay vs {col}')
    axes[row_index, col_index].set_xlabel('TotalPay')
    axes[row_index, col_index].set_ylabel(col)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ###7- Summary of Insights: Write a brief report summarizing the findings and insights from the analyses.
#
#
# ---

# %% [markdown]
# The data set which we worked with was for studying the financial issues for group of employees.
# at first I perform some of exploratory data analysis to deeply understand and identify patterns within the data and explore relationships between numerical variables.
#
# Here are the resulting summary keys and insights :
#
#
# The dataset contains 148654 rows and 13 columns
#
#
# There are unnecessary columns which I decided to drop:
# Notes and Status : full of missing values
# Agency : No variance (all employees have the same agency)
# Id: Not necessary for analysis.
#
#
# Descriptive Statistics:
# 25% of the total pay values are above 36211.030000
# 75% of the total pay values are below 105859.690000
# which indicates that there are outliers.
# the statistics clearly shows outliers in every pay or benefits columns, which is not logical.
# I decided to drop the negative values but keep the max values.
#
#
# Dealing with missing values:
#
# Drop null values in (OvertimePay,OtherPay)
#
# Explanation: small neglected number of missing values compared to total
#
#
# I noticed that there are some rows in which all values are zeros or missing. so, I decided to drop these rows (26 rows)
#
#
# Fill null values in (BasePay)
#
# Explanation: BasePay = TotalPay - OtherPay + OvertimePay
#
#
# Fill null values in (Benefits)
#
# Explanation: Benefits= TotalPayBenefits-TotalPay
#
#
# Data Visualization:
#
# The histogram shows that the most salaries are ranges between 0 and 200000. also it shows that the values are not normally distributed.
#
#
# The pie chart shows the proportion of employees in different departments.
#
#
# Grouped Analysis:
#
# Grouping the data by department allowed us to observe variations in average salaries across different departments. This can be useful for HR and management in understanding salary distributions and making informed decisions.
#
#
# Correlation Analysis:
#
# For correlation analysis, I used heat map which shows that there are strong correlation between 'BasePay', 'Benefits', 'TotalPay' and 'TotalPayBenefits'.
#
#
# also the scatter plots between TotalPay and the other numerical columns shows the increasing lenear relationship between them.

# %% [markdown]
# # Good Luck!
